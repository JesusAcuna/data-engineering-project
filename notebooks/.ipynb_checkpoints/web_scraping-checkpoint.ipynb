# %%
#!pip install lxml
#!pip install requests
#!pip install beautifulsoup4

# %%
import requests
import os
from collections import defaultdict
from bs4 import BeautifulSoup

html_text=requests.get('https://web.ins.gob.pe/es/alimentacion-y-nutricion/vigilancia-alimentaria-y-nutricional/vigilancia-del-sistema-de-informacion-del-estado-nutricional-en-%20EESS').text
soup=BeautifulSoup(html_text,'lxml')

# %%
block=soup.find("main",class_="l-bl block block-main-content") 
li_tags= block.find_all('li')

first_filter = "Indicadores"
 
year_list=list(range(2017,2023))
second_filter=[str(i)for i in year_list]

names_dict=defaultdict(list)
urls_dict=defaultdict(list)

for li_tag in li_tags:
    li_text = li_tag.a.text.replace("\xa0", " ")
    if first_filter in li_text:
        if any((match := substring) in li_text for substring in second_filter):
            names_dict[match].append(li_text)
            li_url = li_tag.a['href']
            urls_dict[match].append(li_url)

# %%
def convert_month_to_number(value_name):
    Months=['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Setiembre','Septiembre','Octubre','Noviembre','Diciembre']
    Months_map=['01','02','03','04','05','06','07','08','09','09','10','11','12']

    months_dict=dict(zip(Months, Months_map))

    names_dict_new=[]

    for month in Months:
        if month in value_name:
            names_dict_new.append(months_dict.get(month,"There's no value for that month in 'months_dict'"))    
    
    num_dict_new = ""
    for i in names_dict_new:
        num_dict_new=num_dict_new+i+"_"
        
    return num_dict_new[:-1]

# %%
if not os.path.exists("./data"):
    os.mkdir("./data")  

for i in list(names_dict.keys()):
    if not os.path.exists(f"./data/{i}"):
        os.mkdir(f"./data/{i}")
    if not os.path.exists(f"./data/{i}/pregnant_women"):
        os.mkdir(f"./data/{i}/pregnant_women")
    if not os.path.exists(f"./data/{i}/children"):
        os.mkdir(f"./data/{i}/children") 

years = names_dict.keys()

        
for year in years:
    print(f"{year}:")
    
    value_name_list=names_dict.get(year,"there's no value_name for that year")
    value_url_list=urls_dict.get(year,"there's no value_url for that year")
    
    for i,value_name in enumerate(value_name_list):
        num_dict_new=convert_month_to_number(value_name)
        
        if "Gestantes" in value_name:
            if "web.ins.gob.pe" in value_url_list[i]:
                URL=value_url_list[i]
                print("pregnant_women if")
                print(URL)
                file_name=f"pregnant_women_{year}_{num_dict_new}"
                response = requests.get(URL)
                open(f"./data/{year}/pregnant_women/{file_name}.xlsx", "wb").write(response.content)

                continue
            else:
                URL="https://web.ins.gob.pe"+value_url_list[i]
                print("pregnant_women else")
                print(URL)
                file_name=f"pregnant_women_{year}_{num_dict_new}"
                response = requests.get(URL)
                open(f"./data/{year}/pregnant_women/{file_name}.xlsx", "wb").write(response.content)

                continue
                        
        elif ("Niños Venezolanos" or "Niños Extranjeros") in value_name:
            if not os.path.exists(f"./data/{year}/foreign_children"):
                os.mkdir(f"./data/{year}/foreign_children") 
            
            if "web.ins.gob.pe" in value_url_list[i]:
                URL=value_url_list[i]
                print("foreign_children if")
                print(URL)
                file_name=f"foreign_children_{year}_{num_dict_new}"
                response = requests.get(URL)
                open(f"./data/{year}/foreign_children/{file_name}.xlsx", "wb").write(response.content)

                continue
            else:
                URL="https://web.ins.gob.pe"+value_url_list[i]
                print("foreing_children else")
                print(URL)
                file_name=f"foreign_children_{year}_{num_dict_new}"
                response = requests.get(URL)
                open(f"./data/{year}/foreign_children/{file_name}.xlsx", "wb").write(response.content)

                continue
        elif "Niños VRAEM" in value_name:
            if not os.path.exists(f"./data/{year}/VRAEM_children"):
                os.mkdir(f"./data/{year}/VRAEM_children") 
            
            if "web.ins.gob.pe" in value_url_list[i]:
                URL=value_url_list[i]
                print("VRAEM_children if")
                print(URL)
                file_name=f"VRAEM_children_{year}_{num_dict_new}"
                response = requests.get(URL)
                open(f"./data/{year}/VRAEM_children/{file_name}.xlsx", "wb").write(response.content)

                continue
            else:
                URL="https://web.ins.gob.pe"+value_url_list[i]
                print("VRAEM_children else")
                print(URL)
                file_name=f"VRAEM_children_{year}_{num_dict_new}"
                response = requests.get(URL)
                open(f"./data/{year}/VRAEM_children/{file_name}.xlsx", "wb").write(response.content)

                continue
        else:
            if "web.ins.gob.pe" in value_url_list[i]:
                URL=value_url_list[i]
                print("children if")
                print(URL)
                file_name=f"children_{year}_{num_dict_new}"
                response = requests.get(URL)
                open(f"./data/{year}/children/{file_name}.xlsx", "wb").write(response.content)

                continue
                
            elif "gob.pe" in value_url_list[i]:
                URL="https://cdn.www.gob.pe/uploads/document/file/3566498/1.Indic%20Ni%C3%B1os%20a%20Junio%202022%20-%20PERU.xlsx?v=1661961860"
                print("children elif")
                print(URL)
                file_name=f"children_{year}_{num_dict_new}"
                response = requests.get(URL)
                open(f"./data/{year}/children/{file_name}.xlsx", "wb").write(response.content)
                
                continue
            else:
                URL="https://web.ins.gob.pe"+value_url_list[i]
                print("children else")
                print(URL)
                file_name=f"children_{year}_{num_dict_new}"
                response = requests.get(URL)
                open(f"./data/{year}/children/{file_name}.xlsx", "wb").write(response.content)
                
                continue
                
    print()
print("End of program")
# Out:
# 2022:
# pregnant_women else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2022/2.Indic%20Gestantes%20Enero_Septiembre%202022.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2022/1.Indic%20Ni%C3%B1os%20a%20Septiembre%202022%20-%20PERU.xlsx
# foreing_children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2022/3.Indic%20Ni%C3%B1os%20a%20Septiembre%202022%20-%20VEN.xlsx
# VRAEM_children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2022/3.Indic%20Ni%C3%B1os%20a%20Septiembre%202022%20-%20VRAEM.xlsx
# pregnant_women else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2022/1.Indic%20Gestantes%20a%20Junio%202022.xlsx
# children elif
# https://cdn.www.gob.pe/uploads/document/file/3566498/1.Indic%20Ni%C3%B1os%20a%20Junio%202022%20-%20PERU.xlsx?v=1661961860
# foreing_children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2022/1.Indic%20Ni%C3%B1os%20a%20Junio%202022%20-%20VEN.xlsx
# VRAEM_children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2022/1.Indic%20Ni%C3%B1os%20a%20Junio%202022%20-%20VRAEM.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2022/1.Indic%20Ni%C3%B1os%20a%20Marzo%202022%20-%20PERU.xlsx
# foreing_children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2022/1.Indic%20Ni%C3%B1os%20a%20Marzo%202022%20-%20VEN.xlsx
# VRAEM_children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2022/1.Indic%20Ni%C3%B1os%20a%20Marzo%202022%20-%20VRAEM.xlsx
#
# 2021:
# pregnant_women else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Gestantes%20Enero_Diciembre%202021.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Ni%C3%B1os%20a%20Diciembre%202021%20-%20PERU_0.xlsx
# foreing_children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Ni%C3%B1os%20a%20Diciembre%202021%20-%20VEN_0.xlsx
# VRAEM_children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Ni%C3%B1os%20a%20Diciembre%202021%20-%20VRAEM_0.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Ni%C3%B1os%20a%20Noviembre%202021%20-%20PERU.xlsx
# foreing_children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Ni%C3%B1os%20a%20Noviembre%202021%20-%20VEN.xlsx
# VRAEM_children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Ni%C3%B1os%20a%20Noviembre%202021%20-%20VRAEM.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Ni%C3%B1os%20a%20Octubre%202021%20-%20PERU.xlsx
# foreing_children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Ni%C3%B1os%20a%20Octubre%202021%20-%20VEN.xlsx
# VRAEM_children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Ni%C3%B1os%20a%20Octubre%202021%20-%20VRAEM.xlsx
# pregnant_women else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Gestantes%20Enero_Septiembre%202021.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Ni%C3%B1os%20a%20Septiembre%202021%20-%20PERU.xlsx
# foreing_children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Ni%C3%B1os%20a%20Septiembre%202021%20-%20VEN.xlsx
# VRAEM_children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Ni%C3%B1os%20a%20Septiembre%202021%20-%20VRAEM.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Ni%C3%B1os%20Enero%20a%20Agosto%202021.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1_indic_ninos_julio_2021_per.xlsx
# pregnant_women else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Gestantes%20Enero_Junio%202021.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Ni%C3%B1os%20a%20Junio%202021%20-%20PER2.xlsx
# foreing_children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Ni%C3%B1os%20a%20Junio%202021%20-%20VEN2.xlsx
# VRAEM_children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Ni%C3%B1os%20a%20Junio%202021%20-%20VRAEM2.xlsx
# foreing_children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Ni%C3%B1os%20a%20Junio%202021%20-%20VEN.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Ni%C3%B1os%20a%20Junio%202021%20-%20PER.xlsx
# VRAEM_children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Ni%C3%B1os%20a%20Junio%202021%20-%20VRAEM.xlsx
# pregnant_women else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Gestantes%20Enero_Marzo%20SIEN%202021.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Ni%C3%B1os%20a%20Marzo%20HIS%202021.xlsx
# VRAEM_children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Ni%C3%B1os%20a%20Marzo%202021%20-%20VRAEM.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2021/1.Indic%20Ni%C3%B1os%20a%20Marzo%202021%20-%20EXTR.xlsx
#
# 2020:
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2020/1.Indic%20Ninos%20%20Enero_Diciembre%20SIEN%202020.xlsx
# pregnant_women else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2020/1.Indic%20Gestantes%20Enero_Diciembre%20SIEN%202020.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2020/A.Indic.%20Ni%C3%B1os%20a%20Dic%202020.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2020/C.Indic.%20Ni%C3%B1os%20a%20Dic%202020%20-%20EXTRAN.xlsx
# pregnant_women else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2020/2.Indic%20Gestantes%20Ene_Dic%202020%20-%20VRAEM.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2020/B.Indic.%20Ni%C3%B1os%20a%20Dic%202020%20-%20VRAEM.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2020/indicadores_nino_enero_septiembre_2020.xlsx
# pregnant_women else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2020/indicadores_gestantes_enero_septiembre_2020.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2019/indicadores_nino_enero_junio_2020_base_datos_his_minsa_v2.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2019/indicadores_nino_enero_marzo_2020_base_datos_his_minsa.xlsx
#
# 2019:
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2019/indicadores_ninos_enero_diciembre_2019_base_datos_his_minsa.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2019/indicadores_ninos_enero_diciembre_2019.xlsx
# pregnant_women else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2019/indicadores_gestantes_enero_diciembre_2019.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2019/SIEN%20Indicadores%20Ninos%20Enero_Septiembre%202019.xlsx
# pregnant_women else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2019/SIEN%20Indicadores%20Gestantes%20Enero_Septiembre%202019.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2019/reporte_de_indicadores_del_hisminsa_2019_enero-septiembre.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2019/indicadores_ninos_enero_junio_2019.xlsx
# pregnant_women else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2019/indicadores_gestantes_enero_junio_2019.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2019/indicadores_ninos_i_trim_2019.xlsx
# pregnant_women else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/2019/indicadores_gestantes_i_trim_2019.xlsx
#
# 2018:
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/indicadores_ninos_enero_diciembre_2018.xlsx
# pregnant_women else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/indicadores_gestantes_enero_diciembre_2018.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/Indicadores%20Ninos%20a%20Junio%202018%20-%20V4.xlsx
# pregnant_women else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/Indicadores%20Gestantes%20a%20Junio%202018%20-%20V4.xlsx
# children if
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/Indicadores%20Ninos%20a%20Marzo%202018%20V2.xlsx
# pregnant_women if
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/Indicadores%20Gestantes%20a%20Marzo%202018%20-%20V2.xlsx
#
# 2017:
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/Indicadores%20Ninos%202017%20Ene-Dic-V5.xlsx
# pregnant_women else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/Indicadores%20Gestantes%202017%20Ene-Diciembre.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/Indicadores%20Ninos%202017%20Ene-Jun.xlsx
# pregnant_women else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/Indicadores%20Gestantes%202017%20Ene-Jun.xlsx
# children else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/Indicadores%20Nios%202017%20Ene-Mar.xlsx
# pregnant_women else
# https://web.ins.gob.pe/sites/default/files/Archivos/cenan/van/informes/Indicadores%20Gestantes%202017%20Ene-Mar.xlsx
#
# End of program
