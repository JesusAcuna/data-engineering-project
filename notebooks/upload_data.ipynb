# %%
import pandas as pd
import openpyxl

# %%
def make_df(year,category,month_ranges,dep):
    df=pd.DataFrame()

    if (("EN" in dep) and ("DIRESA" in dep)) or (("EN" in dep)and("DEP" in dep)):    
        print("1")        
        skiprows=7            
        if category=="children":
            print("children")
            
            if(int(year)==2022):
                usecols="B:U"
                names=['Department',
                        'ITE_DC:Total','ITE_DC:Cases','ITE_DC:Rate',
                        'ITE_RDC:Total','ITE_RDC:Cases','ITE_RDC:Rate',
                        'IPE:Total','IPE_DG:Cases','IPE_DG:Rate',
                        'IPT_DA:Total','IPT_DA:Cases','IPT_DA:Rate',
                        'IPT:Total','IPT_RDA:Cases','IPT_RDA:Rate','IPT_SP:Cases','IPT_SP:Rate','IPT_O:Cases','IPT_O:Rate']
                skipfooter=5                
            elif(int(year)==2020):
                usecols="B:Q"
                names=['Department',
                        'ITE:Total','ITE_DC:Cases','ITE_DC:Rate','ITE_RDC:Cases','ITE_RDC:Rate',
                        'IPE:Total','IPE_DG:Cases','IPE_DG:Rate',
                        'IPT:Total','IPT_DA:Cases','IPT_DA:Rate','IPT_SP:Cases','IPT_SP:Rate','IPT_O:Cases','IPT_O:Rate']
                skipfooter=5                
            else:
                usecols="B:R"
                names=['Department',
                        'ITE_DC:Total','ITE_DC:Cases','ITE_DC:Rate',
                        'ITE_RDC:Total','ITE_RDC:Cases','ITE_RDC:Rate',
                        'IPE:Total','IPE_DG:Cases','IPE_DG:Rate',
                        'IPT:Total','IPT_DA:Cases','IPT_DA:Rate','IPT_SP:Cases','IPT_SP:Rate','IPT_O:Cases','IPT_O:Rate']
                skipfooter=6
            
            
        elif category=="foreign_children":
            print("foreign_children")
            skipfooter=6

        df=pd.read_excel(io=f"./data/{year}/{category}/{category}_{year}_{month_ranges}.xlsx",
                         sheet_name=dep,
                         usecols=usecols,
                         skiprows=skiprows,
                         skipfooter=skipfooter,
                         engine='openpyxl',
                         header=None,
                         names=names)
    elif ("EN" in dep) and ("DISTRITO" in dep):
        print("2")
        skiprows=7

        if category=="children":
            print("children")
            
            if(int(year)==2022):
                usecols="B:X"
                names=['Department','Province','District','Ubigeous',
                        'ITE_DC:Total','ITE_DC:Cases','ITE_DC:Rate',
                        'ITE_RDC:Total','ITE_RDC:Cases','ITE_RDC:Rate',
                        'IPE_DG:Total','IPE_DG:Cases','IPE_DG:Rate',
                        'IPT_DA:Total','IPT_DA:Cases','IPT_DA:Rate',
                        'IPT_RDA:Total','IPT_RDA:Cases','IPT_RDA:Rate','IPT_SP:Cases','IPT_SP:Rate','IPT_O:Cases','IPT_O:Rate']
                skipfooter=7                
            elif(int(year)==2020):
                usecols="B:T"
                names=['Department','Province','District','Ubigeous',
                        'ITE:Total','ITE_DC:Cases','ITE_DC:Rate','ITE_RDC:Cases','ITE_RDC:Rate',
                        'IPE:Total','IPE_DG:Cases','IPE_DG:Rate',
                        'IPT:Total','IPT_DA:Cases','IPT_DA:Rate','IPT_SP:Cases','IPT_SP:Rate','IPT_O:Cases','IPT_O:Rate']
                skipfooter=5                
            else:
                usecols="B:U"
                names=['Department','Province','District','Ubigeous',
                        'ITE_DG:Total','ITE_DC:Cases','ITE_DC:Rate',
                        'ITE_RDG:Total','ITE_RDC:Cases','ITE_RDC:Rate',
                        'IPE:Total','IPE_DG:Cases','IPE_DG:Rate',
                        'IPT:Total','IPT_DA:Cases','IPT_DA:Rate','IPT_SP:Cases','IPT_SP:Rate','IPT_O:Cases','IPT_O:Rate']
                skipfooter=5            
            
        elif category=="foreign_children":
            print("foreign_children")
            skipfooter=5
        elif category=="VRAEM_children":
            print("VRAEM_children")
            skipfooter=6

        df=pd.read_excel(io=f"./data/{year}/{category}/{category}_{year}_{month_ranges}.xlsx",
                         sheet_name=dep,
                         usecols=usecols,
                         skiprows=skiprows,
                         skipfooter=skipfooter,
                         engine='openpyxl',
                         header=None,
                         names=names)

    elif (("Anemia" in dep) and ("DEP" in dep)) or (("Anemia" in dep)and("DIRESA" in dep)):
        print("3")
        usecols='B:K'
        skiprows=6
        names=['Department','Total',
               'AT:Cases','AT:Rate',
               'AL:Cases','AL:Rate',
               'AM:Cases','AM:Rate',
               'AS:Cases','AS:Rate']
        
        if category=="children":
            print("children")
            skipfooter=3
        elif category=="foreign_children":
            print("foreign_children")
            skipfooter=4
        elif category=="pregnant_women":
            print("pregnant_women")
            skipfooter=5

        df=pd.read_excel(io=f"./data/{year}/{category}/{category}_{year}_{month_ranges}.xlsx",
                         sheet_name=dep,
                         usecols=usecols,
                         skiprows=skiprows,
                         skipfooter=skipfooter,
                         engine='openpyxl',
                         header=None,
                         names=names)

    elif ("Anemia" in dep) and ("DISTRITO" in dep):
        print("4")
        usecols='B:N'
        skiprows=6
        names=['Department','Province','District','Ubigeous','Total',
               'AT:Cases','AT:Rate',
               'AL:Cases','AL:Rate',
               'AM:Cases','AM:Rate',
               'AS:Cases','AS:Rate']
        
        if category=="children":
            print("children")
            skipfooter=5
        elif category=="foreign_children":
            print("foreign_children")
            skipfooter=3
        elif category=="pregnant_women":
            print("pregnant_women")
            skipfooter=6
        elif category=="VRAEM_children":
            print("VRAEM_children")
            skipfooter=4

        df=pd.read_excel(io=f"./data/{year}/{category}/{category}_{year}_{month_ranges}.xlsx",
                         sheet_name=dep,
                         usecols=usecols,
                         skiprows=skiprows,
                         skipfooter=skipfooter,
                         engine='openpyxl',
                         header=None,
                         names=names)
    #pregnant_women
    elif (("IMC_PG-CLAP" in dep) and ("DEP" in dep)) or (("IMC_PG-CLAP" in dep)and("DIRESA" in dep)):
        print("5")
        print("pregnant_women")
        usecols='B:N'
        skiprows=7
        skipfooter=6
        names=['Department',
        'IMC_PG:Total','IMC_PG_BP:Cases','IMC_PG_BP:Rate','IMC_PG_SP:Cases','IMC_PG_SP:Rate','IMC_PG_O:Cases','IMC_PG_O:Rate',
        'CLAP:Total','CLAP_DP:Cases','CLAP_DP:Rate','CLAP_SP:Cases','CLAP_SP:Rate']

        df=pd.read_excel(io=f"./data/{year}/{category}/{category}_{year}_{month_ranges}.xlsx",
                         sheet_name=dep,
                         usecols=usecols,
                         skiprows=skiprows,
                         skipfooter=skipfooter,
                         engine='openpyxl',
                         header=None,
                         names=names)

    #pregnant_women    
    elif (("IMC_PG-CLAP" in dep) and ("DISTRITO" in dep)):
        print("6")
        print("pregnant_women")
        usecols='B:Q'
        skiprows=7
        skipfooter=7
        names=['Department','Province','District','Ubigeous',
        'IMC_PG:Total','IMC_PG_BP:Cases','IMC_PG_BP:Rate','IMC_PG_SP:Cases','IMC_PG_SP:Rate','IMC_PG_O:Cases','IMC_PG_O:Rate',
        'CLAP:Total','CLAP_DP:Cases','CLAP_DP:Rate','CLAP_SP:Cases','CLAP_SP:Rate']

        df=pd.read_excel(io=f"./data/{year}/{category}/{category}_{year}_{month_ranges}.xlsx",
                         sheet_name=dep,
                         usecols=usecols,
                         skiprows=skiprows,
                         skipfooter=skipfooter,
                         engine='openpyxl',
                         header=None,
                         names=names)

    return df

# %%
year="2022"
category="children"
month_ranges="01_03"

dep="EN 0-35m x DEP"

df=make_df(year=year,category=category,month_ranges=month_ranges,dep=dep)
df
# Out:
# 1
# children
#        Department  ITE_DC:Total  ITE_DC:Cases  ITE_DC:Rate  ITE_RDC:Total  \
# 0        AMAZONAS         20623          4157    20.157106          16466
# 1          ANCASH         23161          4035    17.421528          19126
# 2        APURIMAC          9600          1475    15.364583           8125
# 3        AREQUIPA         20229          1370     6.772455          18859
# 4        AYACUCHO         21160          3329    15.732514          17831
# 5       CAJAMARCA         54329         11341    20.874671          42988
# 6          CALLAO          8629           587     6.802642           8042
# 7           CUSCO         30975          3771    12.174334          27204
# 8    HUANCAVELICA         11276          2433    21.576800           8843
# 9         HUANUCO         23459          3747    15.972548          19712
# 10            ICA         17744          1089     6.137286          16655
# ...

# %%
df.dtypes
# Out:
# Department        object
# ITE_DC:Total       int64
# ITE_DC:Cases       int64
# ITE_DC:Rate      float64
# ITE_RDC:Total      int64
# ITE_RDC:Cases      int64
# ITE_RDC:Rate     float64
# IPE_DG:Total       int64
# IPE_DG:Cases       int64
# IPE_DG:Rate      float64
# IPT_DA:Total       int64
# IPT_DA:Cases       int64
# IPT_DA:Rate      float64
# IPT_RDA:Total      int64
# IPT_RDA:Cases      int64
# IPT_RDA:Rate     float64
# IPT_SP:Cases       int64
# IPT_SP:Rate      float64
# IPT_O:Cases        int64
# IPT_O:Rate       float64
# dtype: object

# %%
year="2017"
category="children"
month_ranges="01_03"

dep="EN 0-35m x DEP"


df=pd.read_excel(io=f"./data/{year}/{category}/{category}_{year}_{month_ranges}.xlsx",
                 sheet_name=dep,
                 #usecols=usecols,
                 #skiprows=skiprows,
                 #skipfooter=skipfooter,
                 engine='openpyxl')
                 #header=None,
                 #names=names)
df
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN  \nCUADRO N°01\nPERÚ: ESTADO NUTRICIONAL EN NIÑ...
# 1          NaN                        PERIODO: ENERO - MARZO 2017
# 2          NaN                                                NaN
# 3          NaN                                       DEPARTAMENTO
# 4          NaN                                                NaN
# 5          NaN                                                NaN
# 6          NaN                                           AMAZONAS
# 7          NaN                                             ÁNCASH
# 8          NaN                                           APURÍMAC
# 9          NaN                                           AREQUIPA
# 10         NaN                                           AYACUCHO
# 11         NaN                                          CAJAMARCA
# 12         NaN                                             CALLAO
# ...

# %%
import pandas as pd
import openpyxl

def read_table(file_name: str, table_name: str) -> pd.DataFrame:
    wb = openpyxl.load_workbook(file_name, read_only= False, data_only = True) # openpyxl does not have table info if read_only is True; data_only means any functions will pull the last saved value instead of the formula
    for sheetname in wb.sheetnames: # pulls as strings
        sheet = wb[sheetname] # get the sheet object instead of string
        if table_name in sheet.tables: # tables are stored within sheets, not within the workbook, although table names are unique in a workbook
            tbl = sheet.tables[table_name] # get table object instead of string
            tbl_range = tbl.ref #something like 'C4:F9'
            break # we've got our table, bail from for-loop
    data = sheet[tbl_range] # returns a tuple that contains rows, where each row is a tuple containing cells
    content = [[cell.value for cell in row] for row in data] # loop through those row/cell tuples
    header = content[0] # first row is column headers
    rest = content[1:] # every row that isn't the first is data
    df = pd.DataFrame(rest, columns = header)
    wb.close()
    return df

# %%
year="2017"
category="children"
month_ranges="01_03"

dep="EN 0-35m x DEP"

df=read_table(file_name=f"./data/{year}/{category}/{category}_{year}_{month_ranges}.xlsx",
           table_name=dep)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[9], line 7
#       3 month_ranges="01_03"
#       5 dep="EN 0-35m x DEP"
# ----> 7 df=read_table(file_name=f"./data/{year}/{category}/{category}_{year}_{month_ranges}.xlsx",
#       8            table_name=dep)
#
# Cell In[8], line 12, in read_table(file_name, table_name)
#      10         tbl_range = tbl.ref #something like 'C4:F9'
#      11         break # we've got our table, bail from for-loop
# ---> 12 data = sheet[tbl_range] # returns a tuple that contains rows, where each row is a tuple containing cells
#      13 content = [[cell.value for cell in row] for row in data] # loop through those row/cell tuples
#      14 header = content[0] # first row is column headers
#
# UnboundLocalError: local variable 'tbl_range' referenced before assignment

# %%
cols_to_use = ['item_type', 'order id', 'order date', 'state', 'priority']

print(lambda x: x.lower() in cols_to_use)
# Out:
# <function <lambda> at 0x000001D53E16A820>

# %%
year="2017"
category="children"
month_ranges="01_03"

filename=f"./data/{year}/{category}/{category}_{year}_{month_ranges}.xlsx"

# %%
import pandas as pd
from openpyxl import load_workbook

wb = load_workbook(filename = filename)

# %%
wb.sheetnames
# Out:
# ['INICIO',
#  'EN 0-35m x DEP',
#  'EN 0-59m x DEP',
#  'EN 0-35m x DIRESA',
#  'EN 0-59m x DIRESA',
#  'EN 0-35m x DISTRITO',
#  'EN 0-59m x DISTRITO',
#  'EN 0-35m x EESS',
#  'EN 0-59m x EESS',
#  'Anemia 6-35m x DEP',
#  'Anemia 6-59m x DEP',
#  'Anemia 6-35m x DIRESA',
#  'Anemia 6-59m x DIRESA',
#  'Anemia 6-35m x DISTRITO',
#  'Anemia 6-59m x DISTRITO',
#  'Anemia 6-35m x EESS',
#  'Anemia 6-59m x EESS']

# %%
sheet = wb['EN 0-35m x DEP']
sheet
# Out:
# <Worksheet "EN 0-35m x DEP">

# %%
dir(sheet)
# Out:
# ['BREAK_COLUMN',
#  'BREAK_NONE',
#  'BREAK_ROW',
#  'HeaderFooter',
#  'ORIENTATION_LANDSCAPE',
#  'ORIENTATION_PORTRAIT',
#  'PAPERSIZE_A3',
#  'PAPERSIZE_A4',
#  'PAPERSIZE_A4_SMALL',
#  'PAPERSIZE_A5',
#  'PAPERSIZE_EXECUTIVE',
#  'PAPERSIZE_LEDGER',
#  'PAPERSIZE_LEGAL',
#  'PAPERSIZE_LETTER',
#  'PAPERSIZE_LETTER_SMALL',
#  'PAPERSIZE_STATEMENT',
#  'PAPERSIZE_TABLOID',
#  'SHEETSTATE_HIDDEN',
#  'SHEETSTATE_VERYHIDDEN',
#  'SHEETSTATE_VISIBLE',
#  '_WorkbookChild__title',
#  '__class__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_cell',
# ...

# %%
#sheet.dimensions
sheet.values
# Out:
# <generator object Worksheet.values at 0x000001D531CF7120>

# %%
sheet.ref()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 sheet.ref()
#
# AttributeError: 'Worksheet' object has no attribute 'ref'
